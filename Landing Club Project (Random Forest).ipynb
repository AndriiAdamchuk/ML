# %% [markdown]
# ## Random Forest Project
# - Classify and predict whether or not the borrower paid back their loan in full
# - Data: lendingclub.com (from 2007-2010)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Loading data, checking details

# %%
loans = pd.read_csv('loan_data.csv')
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
loans.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
loans['credit.policy'].value_counts()
# Out:
# 1    7710
# 0    1868
# Name: credit.policy, dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Let's compare FICO customer score for those who
#
#     1. MEET the credit underwriting criteria of LendingClub.com
#     2. DON'T meet the credit underwriting criteria of LendingClub.com
#
# AND
#
#     1. FULLY PAID
#     2. NOT FULLY PAID

# %%
sns.set_style('whitegrid')

loans_score_1 = loans[loans['credit.policy'] == 1]['fico'].hist(bins=40, color = 'green', figsize = (12,6), label = 'Credit Policy = 1', alpha = 0.5)
loans_score_0 = loans[loans['credit.policy'] == 0]['fico'].hist(bins=40, color = 'red', figsize = (12,6), label = 'Credit Policy = 0', alpha = 0.5)
plt.legend()
plt.xlabel('FICO score')
# Out:
# Text(0.5, 0, 'FICO score')

# %% [markdown]
# As we can see people who have lower fico score usually don't meet credit underwriting criteria of LendingClub.com

# %%
loans_paid_0 = loans[loans['not.fully.paid'] == 1]['fico'].hist(bins=40, color = 'green', figsize = (12,6), label = 'Not Fully Paid = 1', alpha = 0.5)
loans_paid_1 = loans[loans['not.fully.paid'] == 0]['fico'].hist(bins=40, color = 'red', figsize = (12,6), label = 'Not Fully Paid = 0', alpha = 0.5)
plt.legend()
plt.xlabel('FICO score')
# Out:
# Text(0.5, 0, 'FICO score')

# %% [markdown]
# ...

# %%
plt.figure(figsize=(12,6))
sns.countplot(x = 'purpose', data = loans, hue = 'not.fully.paid')
plt.legend()
plt.xlabel('Purpose')
# Out:
# Text(0.5, 0, 'Purpose')

# %%
# let's see trend between FICO score and interest rate

sns.jointplot(x='fico', y='int.rate', data=loans)

# %%
sns.lmplot(x='fico', y='int.rate', data = loans, col='not.fully.paid', hue='credit.policy')

# %% [markdown]
# ### Preparing the Data

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
cat_feats = ['purpose']

# %%
final_data = pd.get_dummies(loans,columns=cat_feats, drop_first=True)

#drop_first=True to avoid multicolinearity issues

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit.policy               9578 non-null   int64
#  1   int.rate                    9578 non-null   float64
#  2   installment                 9578 non-null   float64
#  3   log.annual.inc              9578 non-null   float64
#  4   dti                         9578 non-null   float64
#  5   fico                        9578 non-null   int64
#  6   days.with.cr.line           9578 non-null   float64
#  7   revol.bal                   9578 non-null   int64
#  8   revol.util                  9578 non-null   float64
#  9   inq.last.6mths              9578 non-null   int64
#  10  delinq.2yrs                 9578 non-null   int64
#  11  pub.rec                     9578 non-null   int64
#  12  not.fully.paid              9578 non-null   int64
# ...

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('not.fully.paid', axis=1)
y = final_data['not.fully.paid']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Training a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
predict = dtree.predict(X_test)

print(confusion_matrix(y_test, predict))
print('\n')
print(classification_report(y_test, predict))
# Out:
# [[1993  415]
#  [ 368   98]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84      2408
#            1       0.19      0.21      0.20       466
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.74      0.73      0.73      2874

# %% [markdown]
# ### Training the Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

rfmodel = RandomForestClassifier(n_estimators=500)
rfmodel.fit(X_train, y_train)
predict = rfmodel.predict(X_test)

print(confusion_matrix(y_test, predict))
print('\n')
print(classification_report(y_test, predict))
# Out:
# [[2395   13]
#  [ 456   10]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      2408
#            1       0.43      0.02      0.04       466
#
#     accuracy                           0.84      2874
#    macro avg       0.64      0.51      0.48      2874
# weighted avg       0.77      0.84      0.77      2874

# %% [markdown]
# Understanding a Classification Report

# %% [markdown]
# - Precision — What percent of your predictions were correct?
#     - Precision:- Accuracy of positive predictions.
# - Recall — What percent of the positive cases did you catch?
#     - Recall:- Fraction of positives that were correctly identified.
# - F1 score — What percent of positive predictions were correct?
